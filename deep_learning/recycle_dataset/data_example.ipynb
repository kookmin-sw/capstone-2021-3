# %% [markdown]
# [TF Custom Dataset 만들기](https://www.tensorflow.org/datasets/add_dataset)
# [TF Dataset 사용 예제](https://www.tensorflow.org/tutorials/images/transfer_learning?hl=ko)

# %%
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt

import recycle_dataset

ds, info = tfds.load('recycle_dataset', with_info=True)

# %%
get_label_name = info.features['label'].int2str

# %%
train_ds, test_ds = ds['train'], ds['test']

plt.figure(figsize=(10, 10))
for i, sample in enumerate(train_ds.take(9)):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(sample['image'].numpy().astype('uint8'))
    plt.title(get_label_name(sample['label'].numpy()))
    plt.axis('off')

# %%
plt.figure(figsize=(10, 10))
for i, sample in enumerate(test_ds.take(9)):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(sample['image'].numpy().astype('uint8'))
    plt.title(get_label_name(sample['label'].numpy()))
    plt.axis('off')
